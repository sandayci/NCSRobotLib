# %%
from utils.experiment import Experiment, get_experiments
from utils.plotting import plot_populations, edvs_image
from utils.defaults import *
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg
from matplotlib import rcParams
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd
import os
#matplotlib inline
rcParams['figure.figsize'] = (8.0, 6.0)
# %load_ext autoreload
# %autoreload 2

# adapt to your computer
# log_folder = "/Users/hermann/Dropbox/ETH/9_Semester/NeuroBot/RobotNav_SemesterProject/Data/logs"
log_folder = "/Users/hermann/Dropbox/ETH/9_Semester/NeuroBot/plotting/logs"
snap_folder = "/Users/hermann/Dropbox/ETH/9_Semester/NeuroBot/RobotNav_SemesterProject/Data/snapshots"
#log_folder = "/Users/hermann/Dropbox/ETH/9_Semester/NeuroBot/eDVS_event_display_server_udp/logs"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
exp = Experiment("tuning", log_folder=log_folder, populations=populations)
# exp = Experiment("target_acquisition_8_notthatfast", log_folder=log_folder)
# exp = Experiment("target_acquisition_5", log_folder=log_folder)
exp.experiment_name

plot_populations(exp.df_rolls, {'obstacle left': '#ff4500', 'obstacle right': '#6495ed',
                                'turn left': '#ff4500', 'turn right': '#6495ed',
                                'speed': '#555555',
                                'target': 'black',
                                'edvs layer': 'black'}, s=0.8)
plt.show()

# %%
edvs_image(exp, 7000)
plt.show()
